# %%
import numpy as np
import matplotlib.pyplot as plt

n = 20
p = 1/8
alpha = 1/(n+1)**(p)
omega = 1/(n*(n+1)**(p))
x = np.linspace(1,n,n)
y = np.ones(n)

for i in range(0,n-1):
    y[1+i] = alpha*(x[i]/2) + (1 - alpha)*(1 - omega*x[i])

plt.scatter(x, y, s=8)
