# %%
a_max=10
for a in range(1,a_max+1):
    for b in range(1,a):
        for c in range(1,(-b-a*b)//(-a+b)):
            num = -a*c-a*b*c
            denom = -b-a*b+a*c-b*c
            d = num // denom
            if num == d * denom:
                print([a,b,c,d])
# Out:
# [2, 1, 1, 2]
# [2, 1, 2, 8]
# [3, 1, 1, 3]
# [3, 2, 2, 3]
# [3, 2, 4, 9]
# [3, 2, 5, 15]
# [3, 2, 6, 27]
# [3, 2, 7, 63]
# [4, 2, 2, 4]
# [4, 2, 3, 9]
# [4, 2, 4, 24]
# [4, 3, 3, 4]
# [4, 3, 5, 8]
# [4, 3, 7, 14]
# [4, 3, 9, 24]
# [4, 3, 10, 32]
# [4, 3, 11, 44]
# [4, 3, 12, 64]
# [4, 3, 13, 104]
# [4, 3, 14, 224]
# [5, 2, 2, 5]
# [5, 2, 3, 15]
# [5, 3, 3, 5]
# [5, 3, 4, 8]
# [5, 3, 6, 20]
# [5, 3, 7, 35]
# [5, 3, 8, 80]
# [5, 4, 4, 5]
# [5, 4, 9, 15]
# [5, 4, 12, 25]
# [5, 4, 14, 35]
# [5, 4, 16, 50]
# [5, 4, 18, 75]
# [5, 4, 19, 95]
# [5, 4, 20, 125]
# [5, 4, 21, 175]
# [5, 4, 22, 275]
# [5, 4, 23, 575]
# [6, 2, 2, 6]
# [6, 3, 3, 6]
# [6, 3, 5, 20]
# [6, 3, 6, 48]
# [6, 4, 4, 6]
# [6, 4, 7, 15]
# [6, 4, 8, 20]
# [6, 4, 9, 27]
# [6, 4, 11, 55]
# [6, 4, 12, 90]
# [6, 4, 13, 195]
# [6, 5, 5, 6]
# [6, 5, 7, 9]
# [6, 5, 14, 24]
# [6, 5, 15, 27]
# [6, 5, 17, 34]
# [6, 5, 20, 48]
# [6, 5, 21, 54]
# [6, 5, 23, 69]
# [6, 5, 25, 90]
# [6, 5, 26, 104]
# [6, 5, 28, 144]
# [6, 5, 29, 174]
# ...
